# %% [markdown]
# Teacher's soltions in here, not given to students directly; ***do not share with students***.  Any solutions given to students will be put into repl.it  BXC directory.
# Links to individual repl.it's given via moodle / slide decks.
#
# Classroom:
# https://repl.it/teacher/classrooms/112856

# %% [markdown]
# #Lab 6a
# ## Read this and follow these instructions
# This lab exercise to help you become more familiar with writing python syntax.   You will use if  /  elif / else statements in this lab.
#
# You are going to do some comparisons to use if statements.
#
# ## Remember:
# * input() always returns strings, If you read in numbers you will have to those strings to the appropriate number type, int() for non-decimal numbers and float() for those with decimal numbers.
# * A string in python is a series of characters which can be letters or numbers, enclosed in single 'single' or double "double" or triple """triple""" quotes.
# * An int (integer) in python is a number that does not have a decimal point.
# * A float (floating point)  in python is a number that does not have a decimal point.
#
# To do this exercise you can refer to previous labs you have done, the live code from the
# if lecture (https://repl.it/@campbe13/Lecture-5-code-examples-here)   and my slides on moodle
#
# ## Exercise
# Change the first 3 lines of the code as indicated.
#
# ### AEIOU
# The teacher will do this one with you:
# In this exercise you will write code that reads a letter of the alphabet from the
# user (input()). Use an appropriate prompt to the user.  If the user enters a, e, i, o or u then your program should display a message "the letter is a vowel" followed by the input.
# If the user enters y then your program should display a "sometimes y is a vowel, and sometimes y is a consonant".
# Otherwise your program should display a message indicating that the
# letter is a consonant.
#
# ### Dog Age
# In this exercise you will write code that reads in a  dog's age in years from the user, use an appropriate prompt.    If the age is less than 1 or greater than 25 display an error message.
# Otherwise multiply the age by 7 and display human years (the input)
# and dog years ( multiply by 7 )
#
# Adding one new piece of code at a time, testing then adding the next is a form of a software development method called iterative development that is used by professional programmers.    It allows you to break down your changes into smaller chunks and to be able to pinpoint easily where the problems arise.  It is a practice that can save you time and lessen frustration.
#
# ### Sound Levels
# This is a table of sound levels
# Noise                    Decibel level (dB)
# Jackhammer         130
# Gas lawnmower   106
# Alarm clock         70
# Quiet room           40
#
# In this exercise you will write code that reads a sound level from a user, use an appropriate prompt.  If the user enters a decibel level that matches one of the noises in the table then your program should display a message containing only that noise. Make sure this works before going to the next step.
# If the user enters a number  of decibels between the noises listed then your program should display a message indicating which noises the level is between. Make sure this works before going to the next step.
# Ensure that your program also generates
# reasonable output for a value smaller than the quietest noise in the table, and for a
# value larger than the loudest noise in the table.
# Optional:
# Note above 120 dB can damage hearing in children (WHO) and 140 dB can cause damage in adults, you may want an extra check to display a warning and some ASCII art warning
#
# ### Optional, advanced challenge  Chinese Zodiac
#
# The Chinese zodiac assigns animals to years in a 12 year cycle. One 12 year cycle is
# shown in the table below. The pattern repeats from there, with 2020 being another
# year of the rat,  and 1999 being another year of the rabbit.
# 22 2 If Statement Exercises
# Year Animal
# 2008 Rat
# 2009 Ox
# 2010 Tiger
# 2011 Rabbit
# 2012 Dragon
# 2013 Snake
# 2014 Horse
# 2015 Sheep
# 2016 Monkey
# 2017 Rooster
# 2018 Dog
# 2019 Pig
# Write a program that reads a year from the user and displays the animal associated
# with that year. Your program should work correctly for any year greater than or equal
# to zero, not just the ones listed in the table.
# You could ad ASCII art for the appropriate animals (or just for your own animal)

# %% [markdown]
# ## Solution 1   AEIOU

# %%
# pmcampbell
# 2019-02-25
# AEIOU challenge

# solution 1 using if / elif 

# test for vowels aeiou sometimes y
# tell the user it's a vowel or consonant
# y is both
print ("solution 1 using if with or / elif\n")

letter= input("enter a letter, any letter: ")
print(letter)

if ( letter == "a"):
  print ("the letter is a vowel",letter)
elif ( letter == "e") :
  print ("the letter is a vowel",letter)
elif ( letter == "i") :
  print ("the letter is a vowel",letter)
elif ( letter == "o") :
  print ("the letter is a vowel",letter)
elif ( letter == "u") :
  print ("the letter is a vowel",letter)
elif ( letter == "y") :
  print ("sometimes",letter,"is a vowel",
        "somtimes",letter,"is a consonant")
else :
  print (letter,"is a consonant")

# %% [markdown]
# ## Solution 2 AEIOU

# %%
# pmcampbell
# 2019-02-25
# AEIOU challenge

# solution 2 using if with or / elif 


# test for vowels aeiou sometimes y 
# tell the user it's a vowel or consonant
# y is both
print ("solution 2 using if with or / elif\n")

letter= input("enter a letter, any letter: ")
print(letter)

if ( letter == "a" or letter == "e" or
     letter == "i" or  letter == "o" or
     letter == "u") :
  print ("the letter is a vowel",letter)
elif ( letter == "y") :
  print ("sometimes",letter,"is a vowel",
        "somtimes",letter,"is a consonant")
else :
  print (letter,"is a consonant")

# %% [markdown]
# ## Solution 1 Dog age

# %%
# pmcampbell
# 2019-02-25
# Dog age from human age 

age=int(input("how many years old is your dog? "))

# min 1 max 25
if (age < 1 or age > 25) :
  print(age, " is not a valid age ")
else: 
    print("Your dogs age is ", age, " in human years and ",age*7," in dog years" )
# Out:
# how many years old is your dog? 6
# Your dogs age is  6  in human years and  42  in dog years

# %% [markdown]
# ## Solution 2 Dog age

# %%
# pmcampbell
# 2019-02-25
# Dog age from human age 

age=int(input("how many years old is your dog? "))

# min 1 max 25
if (age >= 1 and age <= 25) :
  print("Your dogs age is ", age, " in human years and ",age*7," in dog years" )
else: 
  print(age, " is not a valid dog age ")
# Out:
# how many years old is your dog? 6
# Your dogs age is  6  in human years and  42  in dog years

# %% [markdown]
# ## Solution 3 Dog Age

# %%
# pmcampbell
# 2019-02-25
# Dog age from human age 

age=int(input("how many years old is your dog? "))

# min 1 max 25
if (age < 1 ) :
  print(age, " is not a valid dog age ")
elif (age > 25) :
  print(age, " is not a valid dog age ")
else :
  print("Your dogs age is ", age, " in human years and ",age*7," in dog years" )
# Out:
# how many years old is your dog? 56
# 56  is not a valid age

# %% [markdown]
# ## Solution Sound Levels

# %%
# pmcampbell
# 2019-02-25
# given a decibel level tell the user about it
# This is a table of sound levels
# Noise          Decibel level (dB)
# Jackhammer      130
# Gas lawnmower   106
# Alarm clock     70
# Quiet room      40
QR=40
ALARM=70
MOWER=106
JACKH=130
DANGER=140

decibel=int(input("Enter the decibel level of the sound: "))

if (decibel == 40 ) :
  print(decibel, " Quiet Room")
elif (decibel == 70 ) :
  print(decibel, " Alarm clock")
elif (decibel == 106 ) :
  print(decibel, " Gas lawnmower")
elif (decibel == 130 ) :
  print(decibel, " Jackhammer")

if (decibel < QR ) :
  print(decibel, "really quiet")
elif (decibel > QR and decibel < ALARM ) :
  print(decibel, "between Quiet Room and Alarm clock")
elif (decibel > ALARM and decibel < MOWER ) :
  print(decibel, " Alarm clock and Gas lawnmower")
elif (decibel > MOWER and decibel < JACKH ) :
  print(decibel, " Gas lawnmower and Jackhammer")
elif (decibel > JACKH and decibel < DANGER ) :
  print(decibel, " REALLY LOUD")
elif (decibel >= DANGER ): 
  print("""
                  ,---------------.
                 ( DANGEROUS MAN!  )
                  `---------------'
                         '
                          \    ,-_
                              ',' )
     /|_\|/_/|              _// ,'
    , ,--,-. .           ,'  / ,
   / ( O _O ) \        _;___    .
   |  (___)'  |        ()/()/   ,
   |.   ,     |        ,>     ,'
  /  '-'\__,' |         |  /',\\
 //|.      \\\ \        '^;  <-^.
 ||| ,     `-'|\\             )  '
 |||        ' |||        _n___|/, |
c  D  '    ,  c  D      -_ ---,'  |
 UU '  '-'   ' UU         U   <   (
     \  __  /                ,.-. ._,.
    __||  ||__              ((   `'- |
   (___/  \___) [lf]      c___)     U
  """)
# Out:
# Enter the decibel level of the sound: 145
#
#                   ,---------------.
#                  ( DANGEROUS MAN!  )
#                   `---------------'
#                          '
#                           \    ,-_
#                               ',' )
#      /|_\|/_/|              _// ,'
#     , ,--,-. .           ,'  / ,
#    / ( O _O ) \        _;___    .
#    |  (___)'  |        ()/()/   ,
#    |.   ,     |        ,>     ,'
#   /  '-'\__,' |         |  /',\
#  //|.      \\ \        '^;  <-^.
#  ||| ,     `-'|\             )  '
#  |||        ' |||        _n___|/, |
# c  D  '    ,  c  D      -_ ---,'  |
#  UU '  '-'   ' UU         U   <   (
#      \  __  /                ,.-. ._,.
#     __||  ||__              ((   `'- |
#    (___/  \___) [lf]      c___)     U

# %% [markdown]
# # Lab 5b input, conversion, if-branching
# ## Read this and follow these instructions
# This lab exercise to help you become more familiar with writing python syntax.   You will use if statements in this lab.
#
# You are going to do some comparisons to use if statements.
#
# ## Remember:
# * input() always returns strings, If you read in numbers you will have to those strings to the appropriate number type, int() for non-decimal numbers and float() for those with decimal numbers.
# * A string in python is a series of characters which can be letters or numbers, enclosed in single 'single' or double "double" or triple """triple""" quotes.
# * An int (integer) in python is a number that does not have a decimal point.
# * A float (floating point)  in python is a number that does not have a decimal point.
#
# ## Exercise
#
# First Run the code to see what it does.    Use lower case: 1st type in dogs, next run type in cats, next run another animal (ex pigs)  This should test all of the lines of code.  Then try entering dog or cat (without the s), what happens?      Can you fix that  ?   Did you notice the "not indented.." statement is always printed?
#
# ## Changes
# 1.  Change the first 3 lines as directed
# 2.  Change the code so that you can enter dog or dogs to get the woof result
# 3. Change the code so that you can enter cat or cats to get the meow result
#
# ### Part 2
#
# 1. Add code to ask the user for their favourite programming language
# 2. If they enter python print Yay Python!   otherwise display How could you, <their response> is not python.  Where you see <...> use their input.
# 3. If they enter python or c  print those are great languages <response>
# 4. If they enter java or lisp print you've got to be kidding <response>
#
# ### Part 3
# 1.  Add code to ask the user their age, this is a number, you will need to convert it to int
# 6. If the age is  18 or over print be sure to vote in the next election
# 6. If the age is less than 20 and greater than 12 print you are a teenager
# 1. If the age is less than 4 and greater than 0 print you are an advanced toddler
# 1. If  the age is less than 1 or greater than 110  print  who are you fooling? otherwise construct 1. a print statement that will display the age they will be in 2030 and a print statement for their age in 2040, and a print statement for the year they will be 100 years old.
#
#
# Adding one new piece of code at a time, testing then adding the next is a form of a software development method called iterative development that is used by professional programmers.    It allows you to break down your changes into smaller chunks and to be able to pinpoint easily where the problems arise.  It is a practice that can save you time and lessen frustration.

# %% [markdown]
# ## starter code

# %%
# your name
# date
# description 

pets = input ("Do you prefer cats or dogs? ")

if (pets == "dogs"):
  print (pets, "say woof")
else: 
  print ("What, not dogs!")
print ("not indented so not part of if ")

if (pets == "cats"):
  print (pets, "say meow")
  print (pets, "disent miaou")

# %% [markdown]
# ## Part 1  favourite pet plural or singular

# %%
# pmcampbell
# 2019-02-25
# Dog age from human age
pets = input ("Do you prefer cats or dogs? ")

if (pets == "dogs" or pets == "dog"):
  print (pets, "say woof")
else: 
  print ("What, not dogs!")
print ("not indented so not part of if ")

if (pets == "cats" or pets = "cat"):
  print (pets, "say meow")
  print (pets, "disent miaou")

# %% [markdown]
# ## Part 2 programming language

# %%
# pmcampbell
# 2019-02-25
# input is programming languages
# some you like some you don't
language = input ("What is your favourite programming language? ")

if (language == "python"):
  print ("Yay Python!")
else: 
  print ("How could you ", language," is not python")
  
if (language == "python" or language == "c"):
  print ("Those are great languages ",language)
elif (language == "java" or language == "lisp"):
  print ("You've got to be kidding ", language," ???")

# %% [markdown]
# ## Part 3 age

# %%
# pmcampbell
# 2019-02-25
# get age as input
# display messages for certain ages

age= int(input ("How old are you? "))

if (age > 18):
  print ("Be sure to vote in the next electon")
  
if (age < 20 and age > 12):
  print ("You are a teenager")
elif (age < 4 and age > 0):
  print ("You are an advanced toddler")
  
if (age < 1 or age > 110):
  print ("Who are you fooling???")
else :
  print ("You will be ", age +(2030-2019), "in 2030")
  print ("You will be ", age +(2040-2019), "in 2040")
  print ("You will be 100 in", 2018+(100-age))
# Out:
# How old are you? 33
# Be sure to vote in the next electon
# You will be  44 in 2030
# You will be  54 in 2040
# You will be 100 in 2085

# %% [markdown]
# #Lab 4b
# student instructions https://repl.it/teacher/assignments/2652780/edit
#
# from repl.it
# ##Read this and follow these instructions
# This lab exercise to help you become more familiar with writing python syntax.   You will use  numbers in this lab, that are hard coded in variables.
#
# You are going to do some conversions for our American friends.
#
# ###Remember:
# * A string in python is a series of characters which can be letters or numbers, enclosed in single 'single' or double "double" or triple """triple""" quotes.
# * An int (integer) in python is a number that does not have a decimal point.
# * A float (floating point)  in python is a number that does not have a decimal point.
#
#
# Don't worry about input, all input is strings, we will do by assigning numbers to variables.
#
# ##Exercise
# First Run the code to see what it does. The code is the beginnings of a chat bot.  I want you to add a few more things.
#
# ###Changes:
# change the first 3 lines as directed
#
# I have done US to Canadian dollars you will do the rest, using the 1. formulas below.
# 1. Canadian to US dollars    canadian =  us * 0.75    ( verify your test  by googling CAD to USD  and plugging in the numbers)
# 1. kilograms to pounds    pound = kg *  2.205
# 1. pounds to kilograms    kg =  pound /  2.205
# 1. litres to US gallons      gallon =   litre / 4.546
# 1. US gallons  to litres     litre   = gallon *  3.785
# 1. Fahrenheit to celsius         C    =  (F  - 32)  * 5/9
# 1. Celsius to fahrenheit         F    =  C * 9/5 + 32
# 1. Print a statement at the end "Coding brought to you by (put your name here)"
#
# Test, then verify your results by googling ex:  canadian to usd, farenheight to centigrade  etc.
#
# Adding one new piece of code at a time, testing then adding the next is a form of a software development method called *iterative development* that is used by professional programmers.    It allows you to break down your changes into smaller chunks and to be able to pinpoint easily where the problems arise.  It is a practice that can save you time and lessen frustration.

# %%
# pmcampbell
# 2019-01-12
# using arithmetic operators to help
# my American friends

# the formula for US to CAD
# every US dollar is worth $1.33 Canadian
print ("Money")
us_dollars = 12.0
canadian_dollars  = us_dollars * 1.33
print ("If you have  US dollars $", us_dollars, "are worth $", canadian_dollars)

# the formula for CAD to US
# every Canadian dollar is worth 0.75 cents  American
canadian_dollars = 10.0
us_dollars = canadian_dollars * 0.75
print ("If you have Canadian dollars $", canadian_dollars,
       "are worth $", us_dollars, " US ")

#kilograms to pounds    pound = kg *  2.205
#pounds to kilograms    kg =  pound /  2.205
print ("\nWeight")
kg = 12.0
lbs = kg * 2.205
print ("If you have  ", kg, "kg that is ", lbs, "lbs")
lbs = 10
kg = lbs / 2.205
print ("If you have  ", lbs, "lbs that is ", kg, "kg")

#litres to US gallons      gallon =   litre / 4.546
#US gallons  to litres     litre   = gallon *  3.785
print ("\nVolume")
litres = 10
gallons = litres / 4.546
print ("If you have  ", litres, "litres that is ", gallons, "US gallons")
gallons = 20
litres =  gallons * 3.785
print ("If you have  ", gallons, "US gallons that is ", litres, "litres" )

#Fahrenheit to celsius         C    =  (F  - 32)  * 5/9
#Celsius to fahrenheit         F    =  C * 9/5 + 32
print ("Temperature")
F = 80
C = (F - 32) * 5/9
print ("If  it's   ", F, " degrees fahrenheit, that is ", C, "degrees celsius")
C = -22
F = C * 9/5 + 32
print ("If  it's   ", C, " degrees celsius, that is ", F, "degrees fahrenheit")

print ( "\n\nCoding brought to you by Tricia ")
# Out:
# Money)
# If you have  US dollars $ 12.0 are worth $ 15.96
# If you have Canadian dollars $ 10.0 are worth $ 7.5  US

# %% [markdown]
# #Lab 4a
#
# student instructions https://repl.it/teacher/assignments/2586528/edit
#
# from repl.it
#
# ##Read this and follow these instructions
# This lab exercise to help you become more familiar with writing python syntax.   You will use  strings in this lab, and a  new function input()  to create a conversation bot.
#
# You are going to ask for input then respond to it, faking a conversation.
#
# Remember:
# A string in python is a series of characters which can be letters or numbers, enclosed in single 'single' or double "double" or triple """triple""" quotes.
# An int (integer) in python is a number that does not have a decimal point.
# (new?) A float (floating point)  in python is a number that does not have a decimal point.
#
# We are going to use input as strings only for now.
# The code on the left has a very familiar print() function uing strings and variables  and the new input () function
# The input() function reads console input.  The following statement displays "What day is today:" followed by a prompt.  When you type something and hit enter whatever is typed is put into (assigned) to day.
#
# ```day = input("What day is today:")```
#
# When you type something and hit enter whatever is typed is put into (assigned) to day, I type Monday:
#
# ```print("Today is ", day)```
#
# To add the sound, what I did:
# Underneath # get a sound   I added code that asked the user for a sound, put it into a variable, then used sound and animal1 in a sentence.   (Pick any sentence)  This is what you will do below:
#
# ##Exercise
# First Run the code to see what it does. The code is the beginnings of a chat bot.  I want you to add a few more things.
#
#
# ###Changes:
# change the first 3 lines as directed
# Under # get an action   add code to do something similar to what I did for the sound  see To add the sound, what I did
# Under # get a colour   add code ...
# Under # get an adjective   add code
# Under # get a reptile  add code
# Under # get a bird  add code
#
# Adding one new piece of code at a time, testing then adding the next is a form of a software development method called iterative development that is used by professional programmers.    It allows you to break down your changes into smaller chunks and to be able to pinpoint easily where the problems arise.  It is a practice that can save you time and lessen frustration.

# %%
# your name
# the date
# what this lab is about   

# get an animal 
animal1 = input("Enter a type of mamal:")
print ("Wow ", animal1, " that's cool ")

# get a sound 
sound = input ("Enter a sound ")
print ("I think a", animal1, "would make this noise ",sound)

# get an action 
# use animal1 & your new variable in a print() statement (more variables if you want)
# you decide on the statement to be displayed
action = input ("enter what your animal can do ")
print (animal1,  " can  ",  sound, " and ", action)

# get a colour
# use animal1 & your new variable in a print() statement  (more variables if you want)
colour = input ("enter a colour ")
print (animal1,  " are usually  ", colour)

# get a descriptive adjective  (fastest, biggest, smallest,  ??est )
# use animal1 & your new variable in a print() statement  (more variables if you want)
adjective = input ("name something that is descriptive ")
print (animal1,  " is  ",  adjective)


# get another animal, a reptile
# use animal1 & your new variable in a print() statement  (more variables if you want)
reptile = input("enter a reptile ")
print (animal1,  "is a mamal", reptile, "is a reptile")

# get another animal, a bird
# use animal1 & your new variable in a print() statement  (more variables if you want)
bird = input("enter a reptile ")
print (animal1,  "is a mamal", bird, "is a bird", reptile, "is a reptile")

# %% [markdown]
# # **Lab** 3a
#
# student instructions https://repl.it/teacher/assignments/2651103/edit
#
# from replit:
# ##Review
# Review some of last week's lab: string variables & literals
# Remember Cardi B ?
#
# ### code to show an example of a variable (this is a comment)
# ```
# name = "Cardi B"
# print (name)                   # display name only
# print ("my name is " + name)   # display name and  some text
# ```
# The interpreter ignores the comments (#)
#
# Paste in the code & try it if you want, you'll do something similar in the exercise.
#
# ##Exercise a quick review:
#
# Use meaningful variable names for everything:
#
# 1. modify the comments as indicated
# 1. create a variable, assign it your  name  (I started it for you )
# 1. create another variable assign it the name of language you are learning
# 1. create another variable assign it the teacher's name (Patricia)
# 1. Display the following   (use your variables to supply the missing information) :   My name is  ---.  I am learning to program in --- .  My teacher is ---
# 1. create another variable, assign it the following image of a snake (python, get it?) use the triple quotes, it's easier.  (It looks wobbly below, but should display OK, don't spend time on it if it does not.)
# 1. Add variables and display the school name and your program if you're on a roll.
# 1. Display the statement Here is a python, followed by the image.
#
#         Y
#       .-^-.
#      /     \\      .- ~ ~ -.
#     ()     ()    /   _ _   `.                     _ _ _
#      \\_   _/    /  /     \\   \\                . ~  _ _  ~ .
#        | |     /  /       \\   \\             .' .~       ~-. `.
#        | |    /  /         )   )           /  /             `.`.
#        \\ \\_ _/  /         /   /           /  /                `'
#         \\_ _ _.'         /   /           (  (
#                         /   /             \\  \\
#                        /   /               \\  \\
#                       /   /                 )  )
#                      (   (                 /  /
#                       `.  `.             .'  /
#                         `.   ~ - - - - ~   .'
#                            ~ . _ _ _ _ . ~
#
#
# Here is an example result

# %%
# PMC
# 2019-02-03
# Lab 3a  review review

myname = "Tricia"
prog_language = "Python"
school = "Dawson College"
school_type = "CEGEP"
teacher = "Patricia"

print ("My name is "+myname)
print ("I am learning to program in ", prog_language)
print ("My teacher is "+ teacher + " at " + school)

python_ascii_art = """
         Y
      .-^-.
     /     \\      .- ~ ~ -.
    ()     ()    /   _ _   `.                     _ _ _
     \\_   _/    /  /     \\   \\                . ~  _ _  ~ .
       | |     /  /       \\   \\             .' .~       ~-. `.
       | |    /  /         )   )           /  /             `.`.
       \\ \\_ _/  /         /   /           /  /                `'
        \\_ _ _.'         /   /           (  (
                        /   /             \\  \\
                       /   /               \\  \\
                      /   /                 )  )
                     (   (                 /  /
                      `.  `.             .'  /
                        `.   ~ - - - - ~   .'
                           ~ . _ _ _ _ . ~"""
print ()
print ("here is a python", python_ascii_art)

python_ascii_art = """
           /^\\/^\\
         _|__|  O|
\\/     /~     \_/ \\
 \\\____|__________/  \\
        \\_______      \\
                `\\   \\                 \\
                  |     |                  \\
                 /      /                    \\
                /     /                        \\
              /      /                         \\ \\
             /     /                            \  \\
           /     /             _----_            \   \\
          /     /           _-~      ~-_         |   |
         (      (        _-~    _--_    ~-_     _/   |
          \      ~-____-~    _-~    ~-_    ~-_-~    /
            ~-_           _-~          ~-_       _-~
               ~--______-~                ~-___-~"""
print ("here is another python", python_ascii_art)
# Out:
# My name is Tricia
# I am learning to program in  Python
# My teacher is Patricia at Dawson College
#
# here is a python
#          Y
#       .-^-.
#      /     \      .- ~ ~ -.
#     ()     ()    /   _ _   `.                     _ _ _
#      \_   _/    /  /     \   \                . ~  _ _  ~ .
#        | |     /  /       \   \             .' .~       ~-. `.
#        | |    /  /         )   )           /  /             `.`.
#        \ \_ _/  /         /   /           /  /                `'
#         \_ _ _.'         /   /           (  (
#                         /   /             \  \
#                        /   /               \  \
#                       /   /                 )  )
#                      (   (                 /  /
#                       `.  `.             .'  /
#                         `.   ~ - - - - ~   .'
#                            ~ . _ _ _ _ . ~
# here is another python
#            /^\/^\
#          _|__|  O|
# \/     /~     \_/ \
# ...

# %% [markdown]
# # Lab 3b
#
# student instructions https://repl.it/teacher/assignments/2610602/edit
#
# copied code from solution given to students [repl.it solution for students](https://repl.it/@campbe13/Lab3b-teachers-solution)
#
# from repl.it
#
# ##Read this and follow these instructions
# This lab exercise to help you become more familiar with writing python syntax and the print command.   You will use numbers and strings in this lab, and a  new function type()
#
# ###Remember:
# * A string in python is a series of characters which can be letters or numbers, enclosed in single 'single' or double "double" or triple """triple""" quotes.
# * An int (integer) in python is a number that does not have a decimal point.
# * (new?) A float (floating point)  in python is a number that does have a decimal point.
#
# The code on the left is mostly what we have seen before,  comments, variables, print() statements, strings and numbers (float and int)
#
# There is something new, the type() command, this will tell you what datatype python is detecting.
#
# Take a minute to read the code and answer:
# * ? how many comments ?
# * ? how many strings?
# * ? how many ints?
# * ? how many floats ?
# * ? predict what it will print ?
#
# Once you've answered all of the above:
# Try it  run the code, (there is a RUN button above the code.)  Were you right?  If not try to see why not.
#
# There is a print statement "this is an integer"  change the code to have a similar statement before all of the other print statements.
#
# Try it again by running the code.
#
# ##Exercise
# Before you start change the first 3 lines as directed, you can keep or delete the code we started with.
#
# Do each of the following, after each one, click run and make sure it works.
#
# 1. Create two variables, assign them each a different integer number
# 1. Display the two numbers, example code: print ("my numbers are",  num1, " and ", num2)  Notice I have commas between everything not plus signs.
# 1. Using each of the arithmetic operators and your variables print the outcome for each operator,  using your variables where the numbers and results show, like this:
# ![alt text]()

# %% [markdown]
# ? how many comments ?     7
#
# ? how many strings?            2
#
# ? how many ints?                  6
#
# ? how many floats ?              2
#
# ? how many variables?          1      some_data
#
# ? predict what it will print ?
# ```
# this is an integer
# 5 < class  int >
# 4 < class int >
# 5.25 < class float >
# what is this <class str>
# ```

# %%
# your name here
# today's date here
# this lab is to work with numbers, more print statements and strings
# 5 is an integer ( no decimal point )
print ("this is an integer")
# the type() functions tells you what datatype python thinks it is
print (5, type(5))
# 5 + 5 is an integer numeric expression   
print ((7-3), type (7-3))
# 5.25 is a floating point number (has a decimal point)
print (5.25, type(5.25) )
some_data = "what is this"
print (some_data, type(some_data))

# %%
# PMC
# 2019-02-03
# Lab 3b solution, using arithmetic operators & variables
author = "PMCampbell"
num1 = 5
num2 = 3

print ("my numbers are",  num1, " and ", num2)
print()
print ("addition       ", num1, "+", num2, " is ",num1+num2)
print ("subtraction    ", num1, "-", num2, "=", num1-num2)
print ("multiplication ", num1 , "*", num2, " is ", num1*num2)
print ("division       ", num1 ,"/", num2, "=", num1/num2)
print ("exponent       ", num1 ,"^", num2, "=", num1**num2)
print ("Brought to you by", author)
# Out:
# my numbers are 5  and  3
#
# addition        5 + 3  is  8
# subtraction     5 - 3 = 2
# multiplication  5 * 3  is  15
# division        5 / 3 = 1.6666666666666667
# exponent        5 ^ 3 = 125
# Brought to you by PMCampbell

# %% [markdown]
# # Lab 3c
#
# student instructions https://repl.it/teacher/assignments/2652780/edit
#
# ***NOTE: if you use this again make it more descriptive, instead of noun use animal, etc***
#
# from repl.it
#
# ##Read this and follow these instructions
# This lab exercise to help you become more familiar with writing python syntax.   You will use  strings in this lab, and a  new function input()   to create a mini mad libs game.
#
# Mad Libs is a game where you supply a list of words of different types (noun, verb, adverb (qualifies a verb/adjective/adverb categories: how, when, where), adjective (descriptive words, applied to nouns: lost cat.)  These words are then inserted into a text that you have not seen.  http://www.madlibs.com/
#
# Our starting text is The quick brown fox jumped over the lazy dog.
# If you finish this exercise quickly you can google for mad libs sheets and try a more complex example to challenge yourself.
#
# ###Remember:
# * A string in python is a series of characters which can be letters or numbers, enclosed in single 'single' or double "double" or triple """triple""" quotes.
# * An int (integer) in python is a number that does not have a decimal point.
# * (new?) A float (floating point)  in python is a number that does not have a decimal point.
#
# The code on the left has a very familiar print() function using strings and variables  and the new input () function
#
# The input() function reads console input.  The following statement displays "What day is today:" followed by a prompt.  When you type something and hit enter whatever is typed is put into (assigned) to day.
#
# ```
# day = input("What day is today:")
# ```
#
# ##Exercise
# Before you start change the first 3 lines as directed.
#
# The code is the beginnings of a mad lib.  I want you to complete the game.  The phrase below has colour,  a verb, nouns, and adjectives.  Instead of typing them into the string I want them to come from the person running the program, as input.
# The quick brown fox jumped over the lazy dog.
# You will have to provide the following using input statements which prompt the user, variables and to change the print statement to accommodate your variables.   I suggest you add one at a time, run and test it, when it is working do the next.
#
# Changes:
# 1. Another noun (dog)
# 1. An adjective, descriptive word (quick)
# 1. A colour  (brown)
# 1. A verb  (jumped)
# 1. Another adjective, descriptive word (lazy)
#
# Adding one new piece of code at a time, testing then adding the next is a form of a software development method called iterative development that is used by professional programmers.    It allows you to break down your changes into smaller chunks and to be able to pinpoint easily where the problems arise.  It is a practice that can save you time and lessen frustration.

# %%
  # PMCampbell
  # 2019-02-03
  # this lab is to create a madlibs game using input () 

  noun1 = input("Enter a noun:")
  noun2 = input("Enter another noun:")

  colour =  input("Enter a colour :")

  adj1 =   input("Enter a descriptive word  :")
  adj2 =   input("Enter another descriptive word  :")

  verb =   input("Enter a verb  :")

  # The quick brown fox jumped over the lazy dog.

  print ()
  print ("My Mad Lib")
  print ("The "+adj1 + " " + colour + " " + noun1 + " "+ verb + " over the " +adj2 + " " +noun2 +".")
# Out:
# Enter a noun:phone
# Enter another noun:lamp
# Enter a colour :puce
# Enter a descriptive word  :wooden
# Enter another descriptive word  :slimy
# Enter a verb  :sit
#
# My Mad Lib
# The wooden puce phone sit over the slimy lamp.
